# %% [markdown]
# ### Visualize the model ###

# %%
import os, sys

repo_root = os.path.dirname(os.getcwd())   # NOTebooks/ → project root
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

print("Project root:", repo_root)
print(sys.path[:3])
# Out:
# Project root: /Users/zayed/Desktop/learning/linear-regression-from-scratch
# ['/Users/zayed/Desktop/learning/linear-regression-from-scratch', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12']

# %%
from src.eval import visualize
from src.model import LinearModel

model = LinearModel(w=2.0, b=1.0)
visualize(model)

# %%
model = LinearModel(w=4.0, b=2.0)
visualize(model)
